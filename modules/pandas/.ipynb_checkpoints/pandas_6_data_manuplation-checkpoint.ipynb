# %%
path = '../../All_data_sets/pandas_dataset/taitanic.csv'

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv(path)

df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# ### create a new Column that stores only the first name of Name column

# %%
df['surname'] = df['Name'].str.split(',').str[0]

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked    surname
# 0      0         A/5 21171   7.2500   NaN        S     Braund
# 1      0          PC 17599  71.2833   C85        C    Cumings
# 2      0  STON/O2. 3101282   7.9250   NaN        S  Heikkinen
# 3      0            113803  53.1000  C123        S   Futrelle
# ...

# %% [markdown]
# ### conver the column name into lower case

# %%
df.rename(columns=str.lower,inplace=True)

# %%
df.head()
# Out:
#    passengerid  survived  pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 name     sex   age  sibsp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    parch            ticket     fare cabin embarked    surname
# 0      0         A/5 21171   7.2500   NaN        S     Braund
# 1      0          PC 17599  71.2833   C85        C    Cumings
# 2      0  STON/O2. 3101282   7.9250   NaN        S  Heikkinen
# 3      0            113803  53.1000  C123        S   Futrelle
# ...

# %%
df['surname'] = df['surname'].str.lower()

# %%
df.head()
# Out:
#    passengerid  survived  pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 name     sex   age  sibsp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    parch            ticket     fare cabin embarked    surname
# 0      0         A/5 21171   7.2500   NaN        S     braund
# 1      0          PC 17599  71.2833   C85        C    cumings
# 2      0  STON/O2. 3101282   7.9250   NaN        S  heikkinen
# 3      0            113803  53.1000  C123        S   futrelle
# ...

# %%
df[ df['name'].str.contains('Owen') ]
# Out:
#      passengerid  survived  pclass                     name   sex   age  \
# 0              1         0       3  Braund, Mr. Owen Harris  male  22.0
# 834          835         0       3   Allum, Mr. Owen George  male  18.0
#
#      sibsp  parch     ticket  fare cabin embarked surname
# 0        1      0  A/5 21171  7.25   NaN        S  braund
# 834      0      0       2223  8.30   NaN        S   allum

# %% [markdown]
# ### Replace the sex column with m and f

# %%
df['sex'] = df['sex'].replace(to_replace={
    'male':'M',
    'female':'F'
})

# %%
df['gender'] = df['sex'].replace(to_replace={
    'male':'M',
    'female':'F'
})

# %%
df.head()
# Out:
#    passengerid  survived  pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 name sex   age  sibsp  parch  \
# 0                            Braund, Mr. Owen Harris   M  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...   F  38.0      1      0
# 2                             Heikkinen, Miss. Laina   F  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)   F  35.0      1      0
# 4                           Allen, Mr. William Henry   M  35.0      0      0
#
#              ticket     fare cabin embarked    surname gender
# 0         A/5 21171   7.2500   NaN        S     braund      M
# 1          PC 17599  71.2833   C85        C    cumings      F
# 2  STON/O2. 3101282   7.9250   NaN        S  heikkinen      F
# ...

# %%
### delete the column

# %%
df.drop(columns="gender",inplace=True)

# %%
df.head()
# Out:
#    passengerid  survived  pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 name sex   age  sibsp  parch  \
# 0                            Braund, Mr. Owen Harris   M  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...   F  38.0      1      0
# 2                             Heikkinen, Miss. Laina   F  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)   F  35.0      1      0
# 4                           Allen, Mr. William Henry   M  35.0      0      0
#
#              ticket     fare cabin embarked    surname
# 0         A/5 21171   7.2500   NaN        S     braund
# 1          PC 17599  71.2833   C85        C    cumings
# 2  STON/O2. 3101282   7.9250   NaN        S  heikkinen
# 3            113803  53.1000  C123        S   futrelle
# ...

# %%
df.columns
# Out:
# Index(['passengerid', 'survived', 'pclass', 'name', 'sex', 'age', 'sibsp',
#        'parch', 'ticket', 'fare', 'cabin', 'embarked', 'surname'],
#       dtype='object')

# %%
def add(row):
    # print(row)
    return row['survived'] + row['pclass']

# %%
df[['survived','pclass']].apply(add,axis=1)
# Out:
# 0      3
# 1      2
# 2      4
# 3      2
# 4      3
#       ..
# 886    2
# 887    2
# 888    3
# 889    2
# 890    3
# Length: 891, dtype: int64

# %%
df.apply(lambda row: row['survived'] + row['pclass'], axis=1)
# Out:
# 0      3
# 1      2
# 2      4
# 3      2
# 4      3
#       ..
# 886    2
# 887    2
# 888    3
# 889    2
# 890    3
# Length: 891, dtype: int64
