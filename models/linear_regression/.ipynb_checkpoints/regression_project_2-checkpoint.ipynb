# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline

# %%
from sklearn.datasets import fetch_california_housing

# %%
dataset = fetch_california_housing()

# %%
dataset.data
# Out:
# array([[   8.3252    ,   41.        ,    6.98412698, ...,    2.55555556,
#           37.88      , -122.23      ],
#        [   8.3014    ,   21.        ,    6.23813708, ...,    2.10984183,
#           37.86      , -122.22      ],
#        [   7.2574    ,   52.        ,    8.28813559, ...,    2.80225989,
#           37.85      , -122.24      ],
#        ...,
#        [   1.7       ,   17.        ,    5.20554273, ...,    2.3256351 ,
#           39.43      , -121.22      ],
#        [   1.8672    ,   18.        ,    5.32951289, ...,    2.12320917,
#           39.43      , -121.32      ],
#        [   2.3886    ,   16.        ,    5.25471698, ...,    2.61698113,
#           39.37      , -121.24      ]])

# %%
dataset.feature_names
# Out:
# ['MedInc',
#  'HouseAge',
#  'AveRooms',
#  'AveBedrms',
#  'Population',
#  'AveOccup',
#  'Latitude',
#  'Longitude']

# %%
dataset.target_names
# Out:
# ['MedHouseVal']

# %%
dataset.target
# Out:
# array([4.526, 3.585, 3.521, ..., 0.923, 0.847, 0.894])

# %%
dataset.DESCR
# Out:
# '.. _california_housing_dataset:\n\nCalifornia Housing dataset\n--------------------------\n\n**Data Set Characteristics:**\n\n:Number of Instances: 20640\n\n:Number of Attributes: 8 numeric, predictive attributes and the target\n\n:Attribute Information:\n    - MedInc        median income in block group\n    - HouseAge      median house age in block group\n    - AveRooms      average number of rooms per household\n    - AveBedrms     average number of bedrooms per household\n    - Population    block group population\n    - AveOccup      average number of household members\n    - Latitude      block group latitude\n    - Longitude     block group longitude\n\n:Missing Attribute Values: None\n\nThis dataset was obtained from the StatLib repository.\nhttps://www.dcc.fc.up.pt/~ltorgo/Regression/cal_housing.html\n\nThe target variable is the median house value for California districts,\nexpressed in hundreds of thousands of dollars ($100,000).\n\nThis dataset was derived from the 1990 U
# ...

# %% [markdown]
# ### Load the dataset

# %%
df = pd.DataFrame( data=dataset.data , columns=dataset.feature_names  )

df.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude
# 0    -122.23
# 1    -122.22
# 2    -122.24
# 3    -122.25
# 4    -122.25

# %%
df['price'] = dataset.target

# %%
df.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude  price
# 0    -122.23  4.526
# 1    -122.22  3.585
# 2    -122.24  3.521
# 3    -122.25  3.413
# 4    -122.25  3.422

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   MedInc      20640 non-null  float64
#  1   HouseAge    20640 non-null  float64
#  2   AveRooms    20640 non-null  float64
#  3   AveBedrms   20640 non-null  float64
#  4   Population  20640 non-null  float64
#  5   AveOccup    20640 non-null  float64
#  6   Latitude    20640 non-null  float64
#  7   Longitude   20640 non-null  float64
#  8   price       20640 non-null  float64
# dtypes: float64(9)
# memory usage: 1.4 MB

# %%
df.describe()
# Out:
#              MedInc      HouseAge      AveRooms     AveBedrms    Population  \
# count  20640.000000  20640.000000  20640.000000  20640.000000  20640.000000
# mean       3.870671     28.639486      5.429000      1.096675   1425.476744
# std        1.899822     12.585558      2.474173      0.473911   1132.462122
# min        0.499900      1.000000      0.846154      0.333333      3.000000
# 25%        2.563400     18.000000      4.440716      1.006079    787.000000
# 50%        3.534800     29.000000      5.229129      1.048780   1166.000000
# 75%        4.743250     37.000000      6.052381      1.099526   1725.000000
# max       15.000100     52.000000    141.909091     34.066667  35682.000000
#
#            AveOccup      Latitude     Longitude         price
# count  20640.000000  20640.000000  20640.000000  20640.000000
# mean       3.070655     35.631861   -119.569704      2.068558
# std       10.386050      2.135952      2.003532      1.153956
# ...

# %%
df.rename(columns=str.lower , inplace=True)

df.head()
# Out:
#    medinc  houseage  averooms  avebedrms  population  aveoccup  latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    longitude  price
# 0    -122.23  4.526
# 1    -122.22  3.585
# 2    -122.24  3.521
# 3    -122.25  3.413
# 4    -122.25  3.422

# %%
sns.pairplot(data = df  )
plt.show()

# %%
corr = df.corr()

# %%
corr
# Out:
#               medinc  houseage  averooms  avebedrms  population  aveoccup  \
# medinc      1.000000 -0.119034  0.326895  -0.062040    0.004834  0.018766
# houseage   -0.119034  1.000000 -0.153277  -0.077747   -0.296244  0.013191
# averooms    0.326895 -0.153277  1.000000   0.847621   -0.072213 -0.004852
# avebedrms  -0.062040 -0.077747  0.847621   1.000000   -0.066197 -0.006181
# population  0.004834 -0.296244 -0.072213  -0.066197    1.000000  0.069863
# aveoccup    0.018766  0.013191 -0.004852  -0.006181    0.069863  1.000000
# latitude   -0.079809  0.011173  0.106389   0.069721   -0.108785  0.002366
# longitude  -0.015176 -0.108197 -0.027540   0.013344    0.099773  0.002476
# price       0.688075  0.105623  0.151948  -0.046701   -0.024650 -0.023737
#
#             latitude  longitude     price
# medinc     -0.079809  -0.015176  0.688075
# houseage    0.011173  -0.108197  0.105623
# averooms    0.106389  -0.027540  0.151948
# avebedrms   0.069721   0.013344 -0.046701
# ...

# %%
plt.figure(figsize=(10,5))
sns.heatmap( data=corr , annot=True )

plt.show()

# %%
X = df.iloc[ : , :-1]
y = df.iloc[:,-1]

# %% [markdown]
# ### Train test slipt

# %%
from sklearn.model_selection import train_test_split

# %%
X_train , X_test , y_train , y_test = train_test_split(X,y,test_size=0.2,random_state=43)

# %%
X_train.shape , X_test.shape , y_train.shape , y_test.shape
# Out:
# ((16512, 8), (4128, 8), (16512,), (4128,))

# %% [markdown]
# ### Standazation

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
X_train_scaled = scaler.fit_transform( X_train )

X_test_scaled = scaler.transform( X_test )

# %% [markdown]
# ### Model Training

# %%
from sklearn.linear_model import LinearRegression

# %%
regression = LinearRegression()

# %%
regression.fit( X_train_scaled , y_train )
# Out:
# LinearRegression()

# %%
regression.coef_
# Out:
# array([ 0.81411619,  0.1152879 , -0.2470169 ,  0.29508183, -0.00626139,
#        -0.03920426, -0.92227882, -0.88753678])

# %%
regression.intercept_
# Out:
# 2.0678371917393386

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error , r2_score

# %%
y_train_pred = regression.predict( X_train_scaled )

y_test_pred = regression.predict( X_test_scaled )

# %%
print( f'Accuracy on the training samples:{ r2_score( y_train , y_train_pred ) }' )

print( f'Accuracy on the testing samples:{ r2_score( y_test , y_test_pred ) }' )
# Out:
# Accuracy on the training samples:0.6032156895237752
# Accuracy on the testing samples:0.6176846817829131

# %%
print('Training Samples Errors')

print( f'Mean Absolute Error:{ mean_absolute_error( y_train , y_train_pred ) }' )

print( f'Mean Squared Error:{ mean_squared_error( y_train , y_train_pred ) }' )
# Out:
# Training Samples Errors
# Mean Absolute Error:0.5330626865108727
# Mean Squared Error:0.5281455390966961

# %%
print('Testing Samples Errors')

print( f'Mean Absolute Error:{ mean_absolute_error( y_test , y_test_pred ) }' )

print( f'Mean Squared Error:{ mean_squared_error( y_test , y_test_pred ) }' )
# Out:
# Testing Samples Errors
# Mean Absolute Error:0.5279579531623942
# Mean Squared Error:0.5098109045448674

# %%
plt.scatter( y_test , y_test_pred )

plt.xlabel('True prediction')

plt.ylabel('Predicted value')

plt.show()

# %%
residules = y_test - y_test_pred

# %%
sns.displot( residules )

plt.show()

# %%
from sklearn.linear_model import Ridge

# %%
ridge = Ridge()

# %%
ridge.fit( X_train_scaled , y_train )
# Out:
# Ridge()

# %%
y_pred = ridge.predict( X_test_scaled )

# %%
print( f'Accuracy on the testing samples:{ r2_score( y_test , y_pred ) }' )
# Out:
# Accuracy on the testing samples:0.6176909815395173

# %% [markdown]
# ### Save the model

# %%
import pickle

# %%
pickle.dump( regression , open( 'regression.pkl' , 'wb' ) )

# %%
# Load the model

model = pickle.load(  open( 'regression.pkl' , 'rb' ) )

# %%
model.predict( X_test_scaled )
# Out:
# array([1.78197324, 1.94892234, 1.52241219, ..., 2.99644258, 1.3668343 ,
#        1.21409251])
